# %%
# Import Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_keys
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_keys
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 732

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                        "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | sakakah
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | salinopolis
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | rypefjord
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | acari
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | camacha
# Processing Record 15 of Set 1 | labutta
# City not found. Skipping
# Processing Record 16 of Set 1 | aklavik
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | honiara
# Processing Record 19 of Set 1 | ajaccio
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 23 of Set 1 | sentyabrskiy
# City not found. Skipping
# Processing Record 24 of Set 1 | caravelas
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | santana
# Processing Record 29 of Set 1 | lompoc
# Processing Record 30 of Set 1 | komsomolskiy
# Processing Record 31 of Set 1 | tukrah
# Processing Record 32 of Set 1 | marawi
# Processing Record 33 of Set 1 | antalya
# Processing Record 34 of Set 1 | hurricane
# Processing Record 35 of Set 1 | alofi
# Processing Record 36 of Set 1 | baruun-urt
# Processing Record 37 of Set 1 | drovyanaya
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | gisborne
# Processing Record 40 of Set 1 | nemuro
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | necochea
# Processing Record 44 of Set 1 | sekoma
# Processing Record 45 of Set 1 | san juan nepomuceno
# Processing Record 46 of Set 1 | zhanaozen
# Processing Record 47 of Set 1 | kavieng
# Processing Record 48 of Set 1 | labuhan
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | saint-augustin
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | bambous virieux
# Processing Record 4 of Set 2 | burgas
# Processing Record 5 of Set 2 | djougou
# Processing Record 6 of Set 2 | nelson bay
# Processing Record 7 of Set 2 | havelock
# Processing Record 8 of Set 2 | yeppoon
# Processing Record 9 of Set 2 | mount gambier
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | hailar
# Processing Record 12 of Set 2 | sehwan
# Processing Record 13 of Set 2 | chaa-khol
# City not found. Skipping
# Processing Record 14 of Set 2 | damnagar
# Processing Record 15 of Set 2 | papetoai
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | nikolskoye
# Processing Record 20 of Set 2 | beyneu
# Processing Record 21 of Set 2 | canutama
# Processing Record 22 of Set 2 | morales
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | muros
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | mys shmidta
# City not found. Skipping
# Processing Record 27 of Set 2 | nong kung si
# Processing Record 28 of Set 2 | pitimbu
# Processing Record 29 of Set 2 | lebu
# Processing Record 30 of Set 2 | hasaki
# Processing Record 31 of Set 2 | sarkand
# Processing Record 32 of Set 2 | gurlan
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | makinsk
# Processing Record 35 of Set 2 | lorengau
# Processing Record 36 of Set 2 | hirara
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | san patricio
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | tigre
# Processing Record 43 of Set 2 | yangjiang
# Processing Record 44 of Set 2 | pahrump
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | alyangula
# Processing Record 47 of Set 2 | mandalgovi
# Processing Record 48 of Set 2 | bargal
# City not found. Skipping
# Processing Record 49 of Set 2 | tautira
# Processing Record 50 of Set 2 | vestmannaeyjar
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | tingrela
# City not found. Skipping
# Processing Record 3 of Set 3 | ubauro
# Processing Record 4 of Set 3 | geraldton
# Processing Record 5 of Set 3 | tornio
# Processing Record 6 of Set 3 | grand river south east
# City not found. Skipping
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | sola
# Processing Record 9 of Set 3 | pisco
# Processing Record 10 of Set 3 | poronaysk
# Processing Record 11 of Set 3 | belushya guba
# City not found. Skipping
# Processing Record 12 of Set 3 | horta
# Processing Record 13 of Set 3 | omboue
# Processing Record 14 of Set 3 | bafq
# Processing Record 15 of Set 3 | melfi
# Processing Record 16 of Set 3 | windhoek
# Processing Record 17 of Set 3 | novikovo
# Processing Record 18 of Set 3 | tikrit
# Processing Record 19 of Set 3 | saint pete beach
# Processing Record 20 of Set 3 | imbituba
# Processing Record 21 of Set 3 | sao joao da barra
# Processing Record 22 of Set 3 | lamar
# Processing Record 23 of Set 3 | chickasha
# Processing Record 24 of Set 3 | axim
# Processing Record 25 of Set 3 | verkhnevilyuysk
# Processing Record 26 of Set 3 | amderma
# City not found. Skipping
# Processing Record 27 of Set 3 | yulara
# Processing Record 28 of Set 3 | cheney
# Processing Record 29 of Set 3 | el dorado
# Processing Record 30 of Set 3 | leshukonskoye
# Processing Record 31 of Set 3 | khuzhir
# Processing Record 32 of Set 3 | havre-saint-pierre
# Processing Record 33 of Set 3 | chapais
# Processing Record 34 of Set 3 | vaitupu
# City not found. Skipping
# Processing Record 35 of Set 3 | tumannyy
# City not found. Skipping
# Processing Record 36 of Set 3 | bengkulu
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | kaitangata
# Processing Record 39 of Set 3 | taoudenni
# Processing Record 40 of Set 3 | vanimo
# Processing Record 41 of Set 3 | mount isa
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping
# Processing Record 43 of Set 3 | pacific grove
# Processing Record 44 of Set 3 | airai
# Processing Record 45 of Set 3 | tuatapere
# Processing Record 46 of Set 3 | kieta
# Processing Record 47 of Set 3 | disna
# Processing Record 48 of Set 3 | tutoia
# Processing Record 49 of Set 3 | lagoa
# Processing Record 50 of Set 3 | clyde river
# Processing Record 1 of Set 4 | katsuura
# Processing Record 2 of Set 4 | sal rei
# Processing Record 3 of Set 4 | rochester
# Processing Record 4 of Set 4 | cabo san lucas
# Processing Record 5 of Set 4 | avarua
# Processing Record 6 of Set 4 | iquique
# Processing Record 7 of Set 4 | ponta do sol
# Processing Record 8 of Set 4 | plymouth
# Processing Record 9 of Set 4 | iqaluit
# Processing Record 10 of Set 4 | teguldet
# Processing Record 11 of Set 4 | maracai
# Processing Record 12 of Set 4 | barrow
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | nizhneyansk
# City not found. Skipping
# Processing Record 15 of Set 4 | yar-sale
# Processing Record 16 of Set 4 | aku
# Processing Record 17 of Set 4 | nishihara
# Processing Record 18 of Set 4 | mitsamiouli
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | mar del plata
# Processing Record 21 of Set 4 | kudahuvadhoo
# Processing Record 22 of Set 4 | morehead
# Processing Record 23 of Set 4 | boueni
# Processing Record 24 of Set 4 | kimbe
# Processing Record 25 of Set 4 | palimbang
# Processing Record 26 of Set 4 | batagay
# Processing Record 27 of Set 4 | ribeira grande
# Processing Record 28 of Set 4 | waddan
# Processing Record 29 of Set 4 | cherskiy
# Processing Record 30 of Set 4 | koslan
# Processing Record 31 of Set 4 | burica
# City not found. Skipping
# Processing Record 32 of Set 4 | chokurdakh
# Processing Record 33 of Set 4 | panjab
# Processing Record 34 of Set 4 | moree
# Processing Record 35 of Set 4 | samarai
# Processing Record 36 of Set 4 | bethel
# Processing Record 37 of Set 4 | cap malheureux
# Processing Record 38 of Set 4 | batie
# Processing Record 39 of Set 4 | laguna
# Processing Record 40 of Set 4 | den helder
# Processing Record 41 of Set 4 | yuanping
# Processing Record 42 of Set 4 | tasiilaq
# Processing Record 43 of Set 4 | mananara
# Processing Record 44 of Set 4 | kabare
# Processing Record 45 of Set 4 | gimli
# Processing Record 46 of Set 4 | arraial do cabo
# Processing Record 47 of Set 4 | taolanaro
# City not found. Skipping
# Processing Record 48 of Set 4 | thompson
# Processing Record 49 of Set 4 | sao filipe
# Processing Record 50 of Set 4 | mosquera
# Processing Record 1 of Set 5 | maicao
# Processing Record 2 of Set 5 | kuminskiy
# Processing Record 3 of Set 5 | ancud
# Processing Record 4 of Set 5 | san vicente
# Processing Record 5 of Set 5 | opobo
# City not found. Skipping
# Processing Record 6 of Set 5 | lerwick
# Processing Record 7 of Set 5 | gouyave
# Processing Record 8 of Set 5 | babanusah
# City not found. Skipping
# Processing Record 9 of Set 5 | bridlington
# Processing Record 10 of Set 5 | vao
# Processing Record 11 of Set 5 | zabaykalsk
# Processing Record 12 of Set 5 | new norfolk
# Processing Record 13 of Set 5 | dingle
# Processing Record 14 of Set 5 | kahului
# Processing Record 15 of Set 5 | alice springs
# Processing Record 16 of Set 5 | samusu
# City not found. Skipping
# Processing Record 17 of Set 5 | chimore
# Processing Record 18 of Set 5 | dalbandin
# Processing Record 19 of Set 5 | rio claro
# Processing Record 20 of Set 5 | namibe
# Processing Record 21 of Set 5 | namatanai
# Processing Record 22 of Set 5 | ronneby
# Processing Record 23 of Set 5 | paso de carrasco
# Processing Record 24 of Set 5 | piranhas
# Processing Record 25 of Set 5 | casablanca
# Processing Record 26 of Set 5 | port keats
# Processing Record 27 of Set 5 | sitka
# Processing Record 28 of Set 5 | geresk
# City not found. Skipping
# Processing Record 29 of Set 5 | burns lake
# Processing Record 30 of Set 5 | srednekolymsk
# Processing Record 31 of Set 5 | surakarta
# Processing Record 32 of Set 5 | athabasca
# Processing Record 33 of Set 5 | kamiiso
# Processing Record 34 of Set 5 | cockburn harbour
# City not found. Skipping
# Processing Record 35 of Set 5 | faya
# Processing Record 36 of Set 5 | te anau
# Processing Record 37 of Set 5 | los llanos de aridane
# Processing Record 38 of Set 5 | hambantota
# Processing Record 39 of Set 5 | tilichiki
# Processing Record 40 of Set 5 | sistranda
# Processing Record 41 of Set 5 | kaeo
# Processing Record 42 of Set 5 | huilong
# Processing Record 43 of Set 5 | mahbubnagar
# Processing Record 44 of Set 5 | anito
# Processing Record 45 of Set 5 | victoria
# Processing Record 46 of Set 5 | la merced
# Processing Record 47 of Set 5 | ilulissat
# Processing Record 48 of Set 5 | constitucion
# Processing Record 49 of Set 5 | esperance
# Processing Record 50 of Set 5 | nuuk
# Processing Record 1 of Set 6 | abashiri
# Processing Record 2 of Set 6 | bridgetown
# Processing Record 3 of Set 6 | ust-kuyga
# Processing Record 4 of Set 6 | tommot
# Processing Record 5 of Set 6 | coffs harbour
# Processing Record 6 of Set 6 | souillac
# Processing Record 7 of Set 6 | fevralsk
# City not found. Skipping
# Processing Record 8 of Set 6 | danielskuil
# Processing Record 9 of Set 6 | hibbing
# Processing Record 10 of Set 6 | waipawa
# Processing Record 11 of Set 6 | guerrero negro
# Processing Record 12 of Set 6 | vilhena
# Processing Record 13 of Set 6 | adrar
# Processing Record 14 of Set 6 | naryan-mar
# Processing Record 15 of Set 6 | ostrovnoy
# Processing Record 16 of Set 6 | afmadu
# City not found. Skipping
# Processing Record 17 of Set 6 | bulgan
# Processing Record 18 of Set 6 | shimoda
# Processing Record 19 of Set 6 | la romana
# Processing Record 20 of Set 6 | champerico
# Processing Record 21 of Set 6 | shchuchye
# City not found. Skipping
# Processing Record 22 of Set 6 | lagunas
# Processing Record 23 of Set 6 | marfino
# Processing Record 24 of Set 6 | tambul
# City not found. Skipping
# Processing Record 25 of Set 6 | masallatah
# Processing Record 26 of Set 6 | ullal
# Processing Record 27 of Set 6 | buala
# Processing Record 28 of Set 6 | villa bruzual
# Processing Record 29 of Set 6 | pizarro
# Processing Record 30 of Set 6 | vigrestad
# Processing Record 31 of Set 6 | kruisfontein
# Processing Record 32 of Set 6 | bilma
# Processing Record 33 of Set 6 | antofagasta
# Processing Record 34 of Set 6 | bonavista
# Processing Record 35 of Set 6 | grindavik
# Processing Record 36 of Set 6 | inhambane
# Processing Record 37 of Set 6 | vila velha
# Processing Record 38 of Set 6 | alta floresta
# Processing Record 39 of Set 6 | zachagansk
# City not found. Skipping
# Processing Record 40 of Set 6 | sindi
# Processing Record 41 of Set 6 | piacabucu
# Processing Record 42 of Set 6 | alizai
# Processing Record 43 of Set 6 | palkonda
# Processing Record 44 of Set 6 | uwayl
# City not found. Skipping
# Processing Record 45 of Set 6 | bilibino
# Processing Record 46 of Set 6 | sumbe
# Processing Record 47 of Set 6 | san andres
# Processing Record 48 of Set 6 | novi pazar
# Processing Record 49 of Set 6 | puri
# Processing Record 50 of Set 6 | canidelo
# Processing Record 1 of Set 7 | sorland
# Processing Record 2 of Set 7 | yatou
# Processing Record 3 of Set 7 | sinnamary
# Processing Record 4 of Set 7 | ust-kamchatsk
# City not found. Skipping
# Processing Record 5 of Set 7 | edd
# Processing Record 6 of Set 7 | olafsvik
# Processing Record 7 of Set 7 | upleta
# Processing Record 8 of Set 7 | gamboma
# Processing Record 9 of Set 7 | tura
# Processing Record 10 of Set 7 | saint george
# Processing Record 11 of Set 7 | puerto madryn
# Processing Record 12 of Set 7 | narsaq
# Processing Record 13 of Set 7 | harper
# Processing Record 14 of Set 7 | warmbad
# Processing Record 15 of Set 7 | raudeberg
# Processing Record 16 of Set 7 | bathsheba
# Processing Record 17 of Set 7 | korla
# Processing Record 18 of Set 7 | tiznit
# Processing Record 19 of Set 7 | purpe
# Processing Record 20 of Set 7 | kribi
# Processing Record 21 of Set 7 | storsteinnes
# Processing Record 22 of Set 7 | bandarbeyla
# Processing Record 23 of Set 7 | tsihombe
# City not found. Skipping
# Processing Record 24 of Set 7 | isilkul
# Processing Record 25 of Set 7 | semporna
# Processing Record 26 of Set 7 | salihorsk
# Processing Record 27 of Set 7 | ciudad bolivar
# Processing Record 28 of Set 7 | saint-joseph
# Processing Record 29 of Set 7 | flinders
# Processing Record 30 of Set 7 | high level
# Processing Record 31 of Set 7 | leningradskiy
# Processing Record 32 of Set 7 | grand centre
# City not found. Skipping
# Processing Record 33 of Set 7 | manavalakurichi
# Processing Record 34 of Set 7 | phnum penh
# City not found. Skipping
# Processing Record 35 of Set 7 | siavonga
# Processing Record 36 of Set 7 | trairi
# Processing Record 37 of Set 7 | port hardy
# Processing Record 38 of Set 7 | teguise
# Processing Record 39 of Set 7 | ibra
# Processing Record 40 of Set 7 | chabahar
# Processing Record 41 of Set 7 | mazatlan
# Processing Record 42 of Set 7 | colombo
# Processing Record 43 of Set 7 | san pedro
# Processing Record 44 of Set 7 | berlevag
# Processing Record 45 of Set 7 | lerici
# Processing Record 46 of Set 7 | swellendam
# Processing Record 47 of Set 7 | dayong
# Processing Record 48 of Set 7 | kita
# Processing Record 49 of Set 7 | faanui
# Processing Record 50 of Set 7 | cidreira
# Processing Record 1 of Set 8 | salalah
# Processing Record 2 of Set 8 | kysyl-syr
# Processing Record 3 of Set 8 | nara
# Processing Record 4 of Set 8 | bredasdorp
# Processing Record 5 of Set 8 | barahan
# Processing Record 6 of Set 8 | vila
# Processing Record 7 of Set 8 | mangan
# Processing Record 8 of Set 8 | masindi
# Processing Record 9 of Set 8 | avera
# Processing Record 10 of Set 8 | kitob
# Processing Record 11 of Set 8 | ulladulla
# Processing Record 12 of Set 8 | platanos
# Processing Record 13 of Set 8 | kathu
# Processing Record 14 of Set 8 | bombay
# Processing Record 15 of Set 8 | dudinka
# Processing Record 16 of Set 8 | attawapiskat
# City not found. Skipping
# Processing Record 17 of Set 8 | ambodifototra
# City not found. Skipping
# Processing Record 18 of Set 8 | provideniya
# Processing Record 19 of Set 8 | verkhneuralsk
# Processing Record 20 of Set 8 | mangai
# Processing Record 21 of Set 8 | ishigaki
# Processing Record 22 of Set 8 | angoram
# Processing Record 23 of Set 8 | namalenga
# Processing Record 24 of Set 8 | petauke
# Processing Record 25 of Set 8 | cazones
# Processing Record 26 of Set 8 | saleaula
# City not found. Skipping
# Processing Record 27 of Set 8 | kokopo
# Processing Record 28 of Set 8 | isangel
# Processing Record 29 of Set 8 | north bend
# Processing Record 30 of Set 8 | kyren
# Processing Record 31 of Set 8 | murray bridge
# Processing Record 32 of Set 8 | malanje
# Processing Record 33 of Set 8 | tucuma
# Processing Record 34 of Set 8 | maningrida
# Processing Record 35 of Set 8 | ajdabiya
# Processing Record 36 of Set 8 | podgornoye
# Processing Record 37 of Set 8 | masyaf
# Processing Record 38 of Set 8 | rocha
# Processing Record 39 of Set 8 | koster
# Processing Record 40 of Set 8 | samalaeulu
# City not found. Skipping
# Processing Record 41 of Set 8 | port-gentil
# Processing Record 42 of Set 8 | tupelo
# Processing Record 43 of Set 8 | methoni
# Processing Record 44 of Set 8 | aswan
# Processing Record 45 of Set 8 | santa maria
# Processing Record 46 of Set 8 | floro
# Processing Record 47 of Set 8 | vostok
# Processing Record 48 of Set 8 | korneuburg
# Processing Record 49 of Set 8 | nome
# Processing Record 50 of Set 8 | ahipara
# Processing Record 1 of Set 9 | nicoya
# Processing Record 2 of Set 9 | nizhniy kuranakh
# Processing Record 3 of Set 9 | mokhsogollokh
# Processing Record 4 of Set 9 | khatima
# Processing Record 5 of Set 9 | coquimbo
# Processing Record 6 of Set 9 | khasan
# Processing Record 7 of Set 9 | raiwind
# Processing Record 8 of Set 9 | peace river
# Processing Record 9 of Set 9 | naantali
# Processing Record 10 of Set 9 | norman wells
# Processing Record 11 of Set 9 | twin falls
# Processing Record 12 of Set 9 | sao joao batista
# Processing Record 13 of Set 9 | shahpur
# Processing Record 14 of Set 9 | westport
# Processing Record 15 of Set 9 | chadan
# Processing Record 16 of Set 9 | never
# Processing Record 17 of Set 9 | upplands-vasby
# City not found. Skipping
# Processing Record 18 of Set 9 | arlit
# Processing Record 19 of Set 9 | nsukka
# Processing Record 20 of Set 9 | halalo
# City not found. Skipping
# Processing Record 21 of Set 9 | nanortalik
# Processing Record 22 of Set 9 | jiuquan
# Processing Record 23 of Set 9 | fayaoue
# Processing Record 24 of Set 9 | darhan
# Processing Record 25 of Set 9 | puke
# Processing Record 26 of Set 9 | cabinda
# Processing Record 27 of Set 9 | ola
# Processing Record 28 of Set 9 | kargasok
# Processing Record 29 of Set 9 | kamenskoye
# City not found. Skipping
# Processing Record 30 of Set 9 | beruwala
# Processing Record 31 of Set 9 | pangnirtung
# Processing Record 32 of Set 9 | sioux lookout
# Processing Record 33 of Set 9 | kirkland lake
# Processing Record 34 of Set 9 | hokitika
# Processing Record 35 of Set 9 | whitehorse
# Processing Record 36 of Set 9 | lima
# Processing Record 37 of Set 9 | iberia
# Processing Record 38 of Set 9 | bakel
# Processing Record 39 of Set 9 | umm lajj
# Processing Record 40 of Set 9 | jibuti
# Processing Record 41 of Set 9 | ambon
# Processing Record 42 of Set 9 | kaa-khem
# Processing Record 43 of Set 9 | luderitz
# Processing Record 44 of Set 9 | leo
# Processing Record 45 of Set 9 | charyshskoye
# Processing Record 46 of Set 9 | keffi
# Processing Record 47 of Set 9 | te kauwhata
# Processing Record 48 of Set 9 | road town
# Processing Record 49 of Set 9 | toungoo
# City not found. Skipping
# Processing Record 50 of Set 9 | chake chake
# Processing Record 1 of Set 10 | hami
# Processing Record 2 of Set 10 | tasbuget
# City not found. Skipping
# Processing Record 3 of Set 10 | rio gallegos
# Processing Record 4 of Set 10 | sao jose da coroa grande
# Processing Record 5 of Set 10 | kloulklubed
# Processing Record 6 of Set 10 | chimbote
# Processing Record 7 of Set 10 | mogocha
# Processing Record 8 of Set 10 | buzmeyin
# Processing Record 9 of Set 10 | morgan city
# Processing Record 10 of Set 10 | burnie
# Processing Record 11 of Set 10 | shubarshi
# Processing Record 12 of Set 10 | yumen
# Processing Record 13 of Set 10 | yanji
# Processing Record 14 of Set 10 | batemans bay
# Processing Record 15 of Set 10 | vardo
# Processing Record 16 of Set 10 | atka
# City not found. Skipping
# Processing Record 17 of Set 10 | yenagoa
# Processing Record 18 of Set 10 | mafinga
# Processing Record 19 of Set 10 | huazhou
# Processing Record 20 of Set 10 | berezyne
# Processing Record 21 of Set 10 | la rioja
# Processing Record 22 of Set 10 | mrirt
# City not found. Skipping
# Processing Record 23 of Set 10 | norcasia
# Processing Record 24 of Set 10 | vitimskiy
# City not found. Skipping
# Processing Record 25 of Set 10 | la ronge
# Processing Record 26 of Set 10 | lokosovo
# Processing Record 27 of Set 10 | maghama
# City not found. Skipping
# Processing Record 28 of Set 10 | rundu
# Processing Record 29 of Set 10 | sabzevar
# Processing Record 30 of Set 10 | ussel
# Processing Record 31 of Set 10 | karamea
# City not found. Skipping
# Processing Record 32 of Set 10 | sakaiminato
# Processing Record 33 of Set 10 | tessalit
# Processing Record 34 of Set 10 | gryazovets
# Processing Record 35 of Set 10 | vaitape
# Processing Record 36 of Set 10 | rumes
# Processing Record 37 of Set 10 | billings
# Processing Record 38 of Set 10 | codrington
# Processing Record 39 of Set 10 | zhigalovo
# Processing Record 40 of Set 10 | dourbali
# Processing Record 41 of Set 10 | saint anthony
# Processing Record 42 of Set 10 | conde
# Processing Record 43 of Set 10 | umzimvubu
# City not found. Skipping
# Processing Record 44 of Set 10 | nueva guinea
# Processing Record 45 of Set 10 | wanlaweyn
# Processing Record 46 of Set 10 | deh rawud
# City not found. Skipping
# Processing Record 47 of Set 10 | beausejour
# Processing Record 48 of Set 10 | norilsk
# Processing Record 49 of Set 10 | speightstown
# Processing Record 50 of Set 10 | adamovka
# Processing Record 1 of Set 11 | casper
# Processing Record 2 of Set 11 | gaspe
# Processing Record 3 of Set 11 | la primavera
# Processing Record 4 of Set 11 | rudnogorsk
# Processing Record 5 of Set 11 | senanga
# Processing Record 6 of Set 11 | saldanha
# Processing Record 7 of Set 11 | caraballeda
# Processing Record 8 of Set 11 | olavarria
# Processing Record 9 of Set 11 | praia da vitoria
# Processing Record 10 of Set 11 | cayenne
# Processing Record 11 of Set 11 | concordia
# Processing Record 12 of Set 11 | santa cecilia
# Processing Record 13 of Set 11 | husavik
# Processing Record 14 of Set 11 | aviles
# Processing Record 15 of Set 11 | touros
# Processing Record 16 of Set 11 | nova venecia
# Processing Record 17 of Set 11 | praia
# Processing Record 18 of Set 11 | lemesos
# City not found. Skipping
# Processing Record 19 of Set 11 | gewane
# Processing Record 20 of Set 11 | flin flon
# Processing Record 21 of Set 11 | kyle
# Processing Record 22 of Set 11 | guiratinga
# Processing Record 23 of Set 11 | fortuna
# Processing Record 24 of Set 11 | manokwari
# Processing Record 25 of Set 11 | naze
# Processing Record 26 of Set 11 | matagami
# Processing Record 27 of Set 11 | talnakh
# Processing Record 28 of Set 11 | juneau
# Processing Record 29 of Set 11 | port macquarie
# Processing Record 30 of Set 11 | saskylakh
# Processing Record 31 of Set 11 | bela vista
# Processing Record 32 of Set 11 | gampola
# Processing Record 33 of Set 11 | yeovil
# Processing Record 34 of Set 11 | alpena
# Processing Record 35 of Set 11 | coihaique
# Processing Record 36 of Set 11 | pita
# Processing Record 37 of Set 11 | uvalde
# Processing Record 38 of Set 11 | fort nelson
# Processing Record 39 of Set 11 | cao bang
# Processing Record 40 of Set 11 | bukama
# Processing Record 41 of Set 11 | jiwani
# Processing Record 42 of Set 11 | broken hill
# Processing Record 43 of Set 11 | riyadh
# Processing Record 44 of Set 11 | kirakira
# Processing Record 45 of Set 11 | fairbanks
# Processing Record 46 of Set 11 | khandyga
# Processing Record 47 of Set 11 | enshi
# Processing Record 48 of Set 11 | alta gracia
# Processing Record 49 of Set 11 | stokmarknes
# Processing Record 50 of Set 11 | klaksvik
# Processing Record 1 of Set 12 | longyearbyen
# Processing Record 2 of Set 12 | gizo
# Processing Record 3 of Set 12 | san jose
# Processing Record 4 of Set 12 | prince rupert
# Processing Record 5 of Set 12 | marcona
# City not found. Skipping
# Processing Record 6 of Set 12 | rodrigues alves
# Processing Record 7 of Set 12 | neuquen
# Processing Record 8 of Set 12 | natalio
# Processing Record 9 of Set 12 | itarema
# Processing Record 10 of Set 12 | moindou
# Processing Record 11 of Set 12 | maloshuyka
# City not found. Skipping
# Processing Record 12 of Set 12 | lavrentiya
# Processing Record 13 of Set 12 | santa cruz
# Processing Record 14 of Set 12 | rio verde de mato grosso
# Processing Record 15 of Set 12 | porto novo
# Processing Record 16 of Set 12 | san quintin
# Processing Record 17 of Set 12 | dubbo
# Processing Record 18 of Set 12 | mamu kanjan
# Processing Record 19 of Set 12 | hualmay
# Processing Record 20 of Set 12 | viedma
# Processing Record 21 of Set 12 | acapulco
# Processing Record 22 of Set 12 | novobirilyussy
# Processing Record 23 of Set 12 | strai
# Processing Record 24 of Set 12 | knysna
# Processing Record 25 of Set 12 | grand-santi
# Processing Record 26 of Set 12 | quelimane
# Processing Record 27 of Set 12 | boyolangu
# Processing Record 28 of Set 12 | dovers
# Processing Record 29 of Set 12 | vysokogornyy
# Processing Record 30 of Set 12 | hamilton
# Processing Record 31 of Set 12 | jiangkou
# Processing Record 32 of Set 12 | muscat
# Processing Record 33 of Set 12 | sibolga
# Processing Record 34 of Set 12 | kinshasa
# Processing Record 35 of Set 12 | college
# Processing Record 36 of Set 12 | kawalu
# Processing Record 37 of Set 12 | marakkanam
# Processing Record 38 of Set 12 | sechura
# Processing Record 39 of Set 12 | folldal
# Processing Record 40 of Set 12 | chik
# Processing Record 41 of Set 12 | ruteng
# Processing Record 42 of Set 12 | rungata
# City not found. Skipping
# Processing Record 43 of Set 12 | lufilufi
# Processing Record 44 of Set 12 | glauchau
# Processing Record 45 of Set 12 | bourail
# Processing Record 46 of Set 12 | shalinskoye
# Processing Record 47 of Set 12 | payson
# Processing Record 48 of Set 12 | west wendover
# Processing Record 49 of Set 12 | dunedin
# Processing Record 50 of Set 12 | santa fe
# Processing Record 1 of Set 13 | pemba
# Processing Record 2 of Set 13 | lazaro cardenas
# Processing Record 3 of Set 13 | udalguri
# Processing Record 4 of Set 13 | yantal
# Processing Record 5 of Set 13 | tiarei
# Processing Record 6 of Set 13 | bonfim
# Processing Record 7 of Set 13 | tailai
# Processing Record 8 of Set 13 | baculin
# Processing Record 9 of Set 13 | aksarka
# Processing Record 10 of Set 13 | agadez
# Processing Record 11 of Set 13 | guilin
# Processing Record 12 of Set 13 | les cayes
# Processing Record 13 of Set 13 | mahebourg
# Processing Record 14 of Set 13 | urengoy
# Processing Record 15 of Set 13 | sisimiut
# Processing Record 16 of Set 13 | mayo
# Processing Record 17 of Set 13 | pathanamthitta
# Processing Record 18 of Set 13 | sheksna
# Processing Record 19 of Set 13 | roald
# Processing Record 20 of Set 13 | antalaha
# Processing Record 21 of Set 13 | lata
# Processing Record 22 of Set 13 | hovd
# Processing Record 23 of Set 13 | koungheul
# Processing Record 24 of Set 13 | wanning
# Processing Record 25 of Set 13 | sertanopolis
# Processing Record 26 of Set 13 | mehamn
# Processing Record 27 of Set 13 | turayf
# Processing Record 28 of Set 13 | tual
# Processing Record 29 of Set 13 | orocue
# Processing Record 30 of Set 13 | alekseyevsk
# Processing Record 31 of Set 13 | ust-maya
# Processing Record 32 of Set 13 | zhanakorgan
# Processing Record 33 of Set 13 | foki
# Processing Record 34 of Set 13 | noumea
# Processing Record 35 of Set 13 | ormara
# Processing Record 36 of Set 13 | itarare
# Processing Record 37 of Set 13 | isernia
# Processing Record 38 of Set 13 | jijiga
# Processing Record 39 of Set 13 | erenhot
# Processing Record 40 of Set 13 | elizabeth city
# Processing Record 41 of Set 13 | semey
# Processing Record 42 of Set 13 | vung tau
# Processing Record 43 of Set 13 | rorvik
# Processing Record 44 of Set 13 | balkanabat
# Processing Record 45 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 13 | bubaque
# Processing Record 47 of Set 13 | buje
# Processing Record 48 of Set 13 | imperia
# Processing Record 49 of Set 13 | padang
# Processing Record 50 of Set 13 | tezu
# Processing Record 1 of Set 14 | fare
# Processing Record 2 of Set 14 | jalu
# Processing Record 3 of Set 14 | grand gaube
# Processing Record 4 of Set 14 | saiha
# Processing Record 5 of Set 14 | hay river
# Processing Record 6 of Set 14 | liverpool
# Processing Record 7 of Set 14 | amarante do maranhao
# Processing Record 8 of Set 14 | asau
# Processing Record 9 of Set 14 | tias
# Processing Record 10 of Set 14 | nouadhibou
# Processing Record 11 of Set 14 | usinsk
# Processing Record 12 of Set 14 | ocos
# Processing Record 13 of Set 14 | kajaani
# Processing Record 14 of Set 14 | puerto leguizamo
# Processing Record 15 of Set 14 | marsh harbour
# Processing Record 16 of Set 14 | tashtagol
# Processing Record 17 of Set 14 | bend
# Processing Record 18 of Set 14 | pervomayskoye
# Processing Record 19 of Set 14 | santiago
# Processing Record 20 of Set 14 | mali
# Processing Record 21 of Set 14 | wageningen
# Processing Record 22 of Set 14 | starogard gdanski
# Processing Record 23 of Set 14 | portland
# Processing Record 24 of Set 14 | statesboro
# Processing Record 25 of Set 14 | turukhansk
# Processing Record 26 of Set 14 | nelson
# Processing Record 27 of Set 14 | udachnyy
# Processing Record 28 of Set 14 | shreveport
# Processing Record 29 of Set 14 | puerto narino
# Processing Record 30 of Set 14 | kadykchan
# City not found. Skipping
# Processing Record 31 of Set 14 | spasskoye
# Processing Record 32 of Set 14 | karaton
# Processing Record 33 of Set 14 | acarau
# Processing Record 34 of Set 14 | pochutla
# Processing Record 35 of Set 14 | okha
# Processing Record 36 of Set 14 | anloga
# Processing Record 37 of Set 14 | barkly west
# Processing Record 38 of Set 14 | babayurt
# Processing Record 39 of Set 14 | boguchany
# Processing Record 40 of Set 14 | mujiayingzi
# Processing Record 41 of Set 14 | lom sak
# Processing Record 42 of Set 14 | rawlins
# Processing Record 43 of Set 14 | akyab
# Processing Record 44 of Set 14 | mwingi
# Processing Record 45 of Set 14 | urubicha
# Processing Record 46 of Set 14 | palasa
# Processing Record 47 of Set 14 | malwan
# City not found. Skipping
# Processing Record 48 of Set 14 | sorong
# Processing Record 49 of Set 14 | sinjai
# Processing Record 50 of Set 14 | chillicothe
# Processing Record 1 of Set 15 | tete
# Processing Record 2 of Set 15 | vikevag
# Processing Record 3 of Set 15 | najran
# Processing Record 4 of Set 15 | ternate
# Processing Record 5 of Set 15 | puerto del rosario
# Processing Record 6 of Set 15 | makakilo city
# Processing Record 7 of Set 15 | tripoli
# Processing Record 8 of Set 15 | udomlya
# Processing Record 9 of Set 15 | manat
# Processing Record 10 of Set 15 | rincon
# Processing Record 11 of Set 15 | denpasar
# Processing Record 12 of Set 15 | puerto quijarro
# Processing Record 13 of Set 15 | masuguru
# Processing Record 14 of Set 15 | palmer
# Processing Record 15 of Set 15 | fort morgan
# Processing Record 16 of Set 15 | crab hill
# City not found. Skipping
# Processing Record 17 of Set 15 | majholi
# Processing Record 18 of Set 15 | paamiut
# Processing Record 19 of Set 15 | shaunavon
# Processing Record 20 of Set 15 | pringsewu
# Processing Record 21 of Set 15 | balurghat
# Processing Record 22 of Set 15 | katete
# Processing Record 23 of Set 15 | eyrarbakki
# Processing Record 24 of Set 15 | seljord
# Processing Record 25 of Set 15 | haverfordwest
# Processing Record 26 of Set 15 | filadelfia
# Processing Record 27 of Set 15 | akhisar
# Processing Record 28 of Set 15 | ruatoria
# City not found. Skipping
# Processing Record 29 of Set 15 | jodhpur
# Processing Record 30 of Set 15 | tank
# Processing Record 31 of Set 15 | priiskovyy
# Processing Record 32 of Set 15 | issoudun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 677

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0         Sakakah      SA  2021-10-28 23:46:08  29.9697   40.2064     67.57
# 1           Vaini      TO  2021-10-28 23:46:09 -21.2000 -175.2000     80.76
# 2       Hithadhoo      MV  2021-10-28 23:46:09  -0.6000   73.0833     82.90
# 3     Salinopolis      BR  2021-10-28 23:46:10  -0.6136  -47.3561     78.10
# 4       Busselton      AU  2021-10-28 23:46:10 -33.6500  115.3333     51.04
# 5       Cape Town      ZA  2021-10-28 23:42:42 -33.9258   18.4232     62.89
# 6  Port Elizabeth      ZA  2021-10-28 23:46:11 -33.9180   25.5701     65.10
# 7       Rypefjord      NO  2021-10-28 23:46:11  70.6333   23.6667     39.67
# 8      Georgetown      MY  2021-10-28 23:46:12   5.4112  100.3354     78.89
# 9    Punta Arenas      CL  2021-10-28 23:45:30 -53.1500  -70.9167     59.11
#
#    Humidity  Cloudiness  Wind Speed      Current Description
# 0        30          59        5.70            broken clouds
# 1        78          75       10.36            broken clouds
# 2        74         100       11.72          overcast clouds
# 3        85          58        7.07            broken clouds
# 4        62          45        6.71         scattered clouds
# 5        71          40        3.00         scattered clouds
# 6        94           0        3.44                clear sky
# 7        87          90       11.50  light intensity drizzle
# 8        88          40        1.01         scattered clouds
# 9        58          90       13.80          overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
